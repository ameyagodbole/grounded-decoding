# %% [markdown]
# # Get ChatGPT responses

# %%
import json
import openai
import os
import pickle
import sys
from tenacity import (
    retry,
    before_sleep_log,
    stop_after_attempt,
    wait_exponential,
)  # for exponential backoff
from tqdm import tqdm

# %%
client = openai.OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
@retry(wait=wait_exponential(min=10, max=120, exp_base=1.62), stop=stop_after_attempt(10), 
       before_sleep=before_sleep_log(sys.stdout, 20)
      )
def call_create_wrapper(**kwargs):
    return client.chat.completions.create(**kwargs)

# %%
with open('../data/search_results/neurips2023_serp_outputs.json') as fin:
    search_results = json.load(fin)

# %%
search_results['Moritz Hardt (Max Planck Institute for Intelligent Systems, Tübingen)']['organic_results']
# Out:
# [{'position': 1,
#   'title': 'Moritz Hardt',
#   'link': 'https://mrtz.org/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://mrtz.org/&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECA0QAQ',
#   'displayed_link': 'https://mrtz.org',
#   'snippet': "I'm a director at the Max Planck Institute for Intelligent Systems. Prior to joining the institute, I was Associate Professor for Electrical Engineering and ...",
#   'snippet_highlighted_words': ['Max Planck Institute for Intelligent Systems'],
#   'missing': ['bio'],
#   'must_include': {'word': 'bio',
#    'link': 'https://www.google.com/search?safe=active&sca_esv=02097b259e5129ad&q=write+a+%22bio%22+for+Moritz+Hardt+(Max+Planck+Institute+for+Intelligent+Systems,+T%C3%BCbingen)&sa=X&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQ5t4CegQIFBAB'},
#   'source': 'Moritz Hardt'},
#  {'position': 2,
#   'title': 'Moritz Hardt appointed a Director at the Max Planck Institute ...',
#   'link': 'https://is.mpg.de/en/news/moritz-hardt-appointed-a-director-at-the-max-planck-institute-for-intelligent-systems',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://is.mpg.de/en/news/moritz-hardt-appointed-a-director-at-the-max-planck-institute-for-intelligent-systems&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECBMQAQ',
#   'displayed_link': 'https://is.mpg.de › news › moritz-hardt-appointed-a-dire...',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7dac05ea6150fbbc84773a824f97fa0d14f.png',
#   'date': 'Oct 11, 2021',
#   'snippet': 'Tübingen – Computer scientist Moritz Hardt, Ph.D., has accepted a call to the Max Planck Institute for Intelligent Systems. He joined the ...',
#   'snippet_highlighted_words': ['Tübingen',
#    'Moritz Hardt',
#    'Max Planck Institute for Intelligent Systems'],
#   'missing': ['write', 'bio'],
#   'source': 'Max Planck Institute for Intelligent Systems'},
#  {'position': 3,
#   'title': 'Moritz Hardt',
#   'link': 'https://openreview.net/profile?id=~Moritz_Hardt1',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://openreview.net/profile%3Fid%3D~Moritz_Hardt1&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECA4QAQ',
#   'displayed_link': 'https://openreview.net › profile › id=~Moritz_Hardt1',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7daefbac836d0d1eb80b231798f6d301a52.png',
#   'snippet': 'Education & Career History. Principal Researcher. Max-Planck-Institute for Intelligent Systems, Max-Planck Institute ... Select a topic or type what you need help ...',
#   'snippet_highlighted_words': ['Max',
#    'Planck',
#    'Institute for Intelligent Systems',
#    'type'],
#   'missing': ['write', 'bio'],
#   'source': 'OpenReview'},
#  {'position': 4,
#   'title': 'Moritz Hardt | EECS at UC Berkeley',
#   'link': 'https://www2.eecs.berkeley.edu/Faculty/Homepages/mhardt.html',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www2.eecs.berkeley.edu/Faculty/Homepages/mhardt.html&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECBAQAQ',
#   'displayed_link': 'https://www2.eecs.berkeley.edu › Homepages › mhardt',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7da594cd14e7b155ed1303b2c3bcc28a5bf.png',
#   'snippet': 'Moritz Hardt is an Associate Professor in the Department of Electrical Engineering and Computer Sciences at the University of California, Berkeley.',
#   'snippet_highlighted_words': ['Moritz Hardt', 'University'],
#   'missing': ['(Max', 'Planck', 'Intelligent', 'Systems,', 'Tübingen)'],
#   'source': 'EECS at Berkeley'},
#  {'position': 5,
#   'title': 'Discovering discrimination in supervised learning',
#   'link': 'https://is.mpg.de/events/moritz-hardt-will-review-some-progress-and-challenges-towards-preventing-discrimination-based-on-sensitive-attributes-in-supervised-learning',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://is.mpg.de/events/moritz-hardt-will-review-some-progress-and-challenges-towards-preventing-discrimination-based-on-sensitive-attributes-in-supervised-learning&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECA8QAQ',
#   'displayed_link': 'https://is.mpg.de › events › moritz-hardt-will-review-som...',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7da6439fb0be7f7017e12edb52e652e706d.png',
#   'date': 'Apr 4, 2017',
#   'snippet': 'Biography: Moritz Hardt is a senior research scientist at Google ... Max Planck Institute for Intelligent Systems. Max-Planck-Ring 4 72076 ...',
#   'snippet_highlighted_words': ['Biography',
#    'Moritz Hardt',
#    'Max Planck Institute for Intelligent Systems'],
#   'missing': ['write'],
#   'must_include': {'word': 'write',
#    'link': 'https://www.google.com/search?safe=active&sca_esv=02097b259e5129ad&q=%22write%22+a+bio+for+Moritz+Hardt+(Max+Planck+Institute+for+Intelligent+Systems,+T%C3%BCbingen)&sa=X&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQ5t4CegQIFRAB'},
#   'source': 'Max Planck Institute for Intelligent Systems'},
#  {'position': 6,
#   'title': 'Max Planck Institute for Intelligent Systems',
#   'link': 'https://www.tuebingen.mpg.de/84502/mpi-fuer-intelligente-systeme',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.tuebingen.mpg.de/84502/mpi-fuer-intelligente-systeme&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECC4QAQ',
#   'displayed_link': 'https://www.tuebingen.mpg.de › mpi-fuer-intelligente-sy...',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7da26c55a84a7be20d5f2291d01cd931113.png',
#   'snippet': 'Moritz Hardt founded the department "Social Foundations of Computation" in 2021, which extends the institute\'s deep expertise in machine learning, artificial ...',
#   'snippet_highlighted_words': ['Moritz Hardt', "institute's", 'artificial'],
#   'missing': ['write'],
#   'must_include': {'word': 'write',
#    'link': 'https://www.google.com/search?safe=active&sca_esv=02097b259e5129ad&q=%22write%22+a+bio+for+Moritz+Hardt+(Max+Planck+Institute+for+Intelligent+Systems,+T%C3%BCbingen)&sa=X&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQ5t4CegQIORAB'},
#   'source': 'Max-Planck-Campus Tübingen'},
#  {'position': 7,
#   'title': 'Moritz Hardt',
#   'link': 'https://scholar.google.com/citations?user=adnTgaAAAAAJ&hl=en',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://scholar.google.com/citations%3Fuser%3DadnTgaAAAAAJ%26hl%3Den&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECCwQAQ',
#   'displayed_link': 'https://scholar.google.com › citations',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7dab08c7c7e431fb9601fc666e4cd272567.png',
#   'snippet': 'Max Planck Institute for Intelligent Systems - \u202a\u202aCited by 29624\u202c\u202c - \u202aalgorithms\u202c - \u202adecision making\u202c - \u202amachine learning\u202c',
#   'snippet_highlighted_words': ['Max Planck Institute for Intelligent Systems'],
#   'missing': ['write', 'bio'],
#   'source': 'Google Scholar'},
#  {'position': 8,
#   'title': 'PhD Students',
#   'link': 'https://learning-systems.org/phds',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://learning-systems.org/phds&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECC0QAQ',
#   'displayed_link': 'https://learning-systems.org › phds',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7dadb748ef98b587f3e59c6d30b4e752847.png',
#   'snippet': 'Alexander Immer. My research focuses on probabilistic machine learning and data science. Currently, I am particularly interested in approximate inference ...',
#   'missing': ['write', 'bio'],
#   'source': 'Max Planck ETH Center for Learning Systems'},
#  {'position': 9,
#   'title': 'Max Planck Institute for Intelligent Systems',
#   'link': 'https://gr.linkedin.com/company/max-planck-institute-for-intelligent-systems?trk=public_profile_experience-item_profile-section-card_image-click',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://gr.linkedin.com/company/max-planck-institute-for-intelligent-systems%3Ftrk%3Dpublic_profile_experience-item_profile-section-card_image-click&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQFnoECDQQAQ',
#   'displayed_link': '18.7K+ followers',
#   'favicon': 'https://serpapi.com/searches/65e6e4defa8675392a432a1c/images/2bab3c074d77b146000c4efe4e70f7da6908d2958a8eab6460194d6725d8a399.png',
#   'snippet': 'We take a highly interdisciplinary approach that combines mathematics, computation, materials science, and biology. The Max Planck Institute for Intelligent ...',
#   'snippet_highlighted_words': ['Max Planck Institute for Intelligent'],
#   'missing': ['write'],
#   'must_include': {'word': 'write',
#    'link': 'https://www.google.com/search?safe=active&sca_esv=02097b259e5129ad&q=%22write%22+a+bio+for+Moritz+Hardt+(Max+Planck+Institute+for+Intelligent+Systems,+T%C3%BCbingen)&sa=X&ved=2ahUKEwjH06jO5tyEAxW2RTABHRQ8BGMQ5t4CegQIOBAB'},
#   'source': 'LinkedIn · Max Planck Institute for Intelligent Systems'}]

# %%
RESPONSE_MODEL = "gpt-3.5-turbo"
TOP_P=1.0
TEMPERATURE=1.0

search_res_gpt_35 = []
for query in tqdm(search_results, desc='Query'):
    one_res = search_results[query]
    one_q = f"Write a bio for {query}\nSearch Results:\n"
    for osr in one_res['organic_results']:
        one_q += f"title: {osr['title']}\nsnippet: {osr['snippet']}\n---\n"
    
    messages = [
                {
                    "role": "system",
                    "content": "Write a short response (one paragraph) using only the information available in the search results."
                },
                {
                    "role": "user",
                    "content": one_q
                }
            ]
    
    # print(messages[0])
    # print(messages[1]['content'])
    # break
    response = call_create_wrapper(
                model=RESPONSE_MODEL,
                messages=messages,
                n=1,
                temperature=TEMPERATURE,
                top_p=TOP_P,
                logprobs=True
    )
    out_to_save = response.dict().copy()
    out_to_save['query'] = query
    out_to_save['organic_results'] = one_res['organic_results']
    search_res_gpt_35.append(out_to_save)
    # print(response)
    # break
# Out:
# Query: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53/53 [01:39<00:00,  1.87s/it]

# %%
with open("../outputs/gpt_35_turbo_gen/neurips2023_serp_gen.pkl", 'wb') as fout:
    pickle.dump(search_res_gpt_35, fout)

# %% [markdown]
# ## Study generations

# %%
import numpy as np

# %%
rng = np.random.default_rng(42)

# %%
rand_idx = rng.choice(len(search_res_gpt_35), 10)

# %%
def display_output(one_out):
    print(f"Query: {one_out['query']}\n\n")
    print(f"Search Results:\n")
    for osr in one_out['organic_results']:
        print(f"title: {osr['title']}\nsnippet: {osr['snippet']}\n---\n")
    print(f"\n{one_out['choices'][0]['message']['content']}\n---\n")
    for one_tok in one_out['choices'][0]['logprobs']['content']:
        print(f"{one_tok['token']}\t{one_tok['logprob']}\n")
    print('\n++++\n')

# %%
for viz_idx in rand_idx:
    display_output(search_res_gpt_35[viz_idx])
# Out:
# Query: Moritz Hardt (Max Planck Institute for Intelligent Systems, Tübingen)
#
#
# Search Results:
#
# title: Moritz Hardt
# snippet: I'm a director at the Max Planck Institute for Intelligent Systems. Prior to joining the institute, I was Associate Professor for Electrical Engineering and ...
# ---
#
# title: Moritz Hardt appointed a Director at the Max Planck Institute ...
# snippet: Tübingen – Computer scientist Moritz Hardt, Ph.D., has accepted a call to the Max Planck Institute for Intelligent Systems. He joined the ...
# ---
#
# title: Moritz Hardt
# snippet: Education & Career History. Principal Researcher. Max-Planck-Institute for Intelligent Systems, Max-Planck Institute ... Select a topic or type what you need help ...
# ---
#
# title: Moritz Hardt | EECS at UC Berkeley
# snippet: Moritz Hardt is an Associate Professor in the Department of Electrical Engineering and Computer Sciences at the University of California, Berkeley.
# ---
#
# title: Discovering discrimination in supervised learning
# snippet: Biography: Moritz Hardt is a senior research scientist at Google ... Max Planck Institute for Intelligent Systems. Max-Planck-Ring 4 72076 ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: Moritz Hardt founded the department "Social Foundations of Computation" in 2021, which extends the institute's deep expertise in machine learning, artificial ...
# ---
#
# title: Moritz Hardt
# snippet: Max Planck Institute for Intelligent Systems - ‪‪Cited by 29624‬‬ - ‪algorithms‬ - ‪decision making‬ - ‪machine learning‬
# ---
#
# title: PhD Students
# snippet: Alexander Immer. My research focuses on probabilistic machine learning and data science. Currently, I am particularly interested in approximate inference ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: We take a highly interdisciplinary approach that combines mathematics, computation, materials science, and biology. The Max Planck Institute for Intelligent ...
# ---
#
#
# Moritz Hardt is a Computer Scientist who has been appointed as a Director at the Max Planck Institute for Intelligent Systems in Tübingen. Previously, he was an Associate Professor for Electrical Engineering and Computer Sciences at UC Berkeley. He has founded a department focused on the "Social Foundations of Computation," expanding the institute's expertise in machine learning and artificial intelligence.
# ---
#
# Mor	-0.0050959494
#
# itz	-1.8624639e-06
#
#  Hard	-3.888926e-06
#
# t	-0.00011427152
#
#  is	-0.13182428
#
#  a	-0.09934075
#
#  Computer	-3.3890634
#
#  Scientist	-0.22221234
#
#  who	-1.5881399
#
#  has	-2.2710612
#
#  been	-0.34854066
#
#  appointed	-0.0011036602
#
#  as	-0.012910191
#
#  a	-0.008552165
#
#  Director	-0.027187146
#
#  at	-0.00012618455
#
#  the	-0.00041267683
#
#  Max	-4.00813e-06
#
#  Plan	-3.3809047e-05
#
# ck	0.0
#
#  Institute	-6.9882217e-06
#
#  for	-1.247159e-05
#
#  Intelligent	-5.080963e-06
#
#  Systems	-1.6166903e-05
#
#  in	-0.061463133
#
#  T	-0.00014621076
#
# ü	-5.5122365e-07
#
# bing	-7.89631e-07
#
# en	-2.8921695e-05
#
# .	-0.028592689
#
#  Previously	-2.6229823
#
# ,	-0.015987912
#
#  he	-0.015421344
#
#  was	-0.55077595
#
#  an	-0.012982916
#
#  Associate	-0.00024108587
#
#  Professor	-1.2664457e-06
#
#  for	-0.830805
#
#  Electrical	-2.3676734e-05
#
#  Engineering	-2.1008714e-06
#
#  and	-0.017630162
#
#  Computer	-0.0062911296
#
#  Sciences	-0.010413667
#
#  at	-0.00060224184
#
#  UC	-0.4916021
#
#  Berkeley	-0.00038479414
#
# .	-0.08677115
#
#  He	-1.2909274
#
#  has	-0.7436421
#
#  founded	-2.8306456
#
#  a	-2.3605998
#
#  department	-0.032647833
#
#  focused	-1.9549329
#
#  on	-6.704273e-07
#
#  the	-0.08476894
#
#  "	-0.035449706
#
# Social	-1.1637165e-05
#
#  Foundations	-0.00016766376
#
#  of	-1.6240566e-06
#
#  Com	-5.5122365e-07
#
# putation	-2.4584822e-06
#
# ,"	-2.7695239
#
#  expanding	-0.8576723
#
#  the	-0.01179008
#
#  institute	-0.049885035
#
# 's	-0.0021043406
#
#  expertise	-0.0704323
#
#  in	-0.0006460758
#
#  machine	-0.06450231
#
#  learning	-7.9418505e-06
#
#  and	-0.037877712
#
#  artificial	-0.0019305398
#
#  intelligence	-2.220075e-06
#
# .	-0.0048888423
#
#
# ++++
#
# Query: Isabelle Guyon (Google and ChaLearn)
#
#
# Search Results:
#
# title: Isabelle Guyon - Google
# snippet: Isabelle Guyon is Director, Research Scientist at Google, in detachment from her position… | Learn more about Isabelle Guyon's work experience, education, ...
# ---
#
# title: Isabelle Guyon
# snippet: Isabelle Guyon is a French-born researcher in machine learning known for her work on support-vector machines, artificial neural networks and bioinformatics.
# ---
#
# title: Isabelle Guyon - ChaLearn
# snippet: Director, Research Scientist, Google Research (since Oct 2022). Chaired Professor of Artificial Intelligence (PR EX1) and INRIA researcher, Machine Learning ...
# ---
#
# title: Isabelle Guyon | IEEE Xplore Author Details
# snippet: Biography. Isabelle Guyon is currently a full professor of data science and machine learning at Université Paris-Saclay, the head master of CS Artifical ...
# ---
#
# title: Isabelle Guyon | MLconf - The Machine Learning ...
# snippet: Bio. Isabelle Guyon is an independent consultant, specialized in statistical data analysis, pattern recognition and machine learning.
# ---
#
# title: Isabelle Guyon
# snippet: Isabelle Guyon. Director of Research, Google; Prof. UPSaclay; President ChaLearn. Verified email at chalearn.org - Homepage · Machine Learning.
# ---
#
# title: Isabelle Guyon
# snippet: Promoting openness in scientific communication and the peer-review process.
# ---
#
# title: Isabelle GUYON | Professor | Professor | Research profile
# snippet: Bayesian optimization (BO) is a widely used approach for computationally expensive black-box optimization such as simulator calibration and hyperparameter ...
# ---
#
# title: DSSC seminar on machine learning: Prof. dr. Isabelle ...
# snippet: Isabelle Guyon is chaired professor in “big data” at the Université Paris-Saclay, specialized in statistical data analysis, pattern recognition and machine ...
# ---
#
# title: Isabelle Guyon
# snippet: List of computer science publications by Isabelle Guyon.
# ---
#
#
# Isabelle Guyon is a respected figure in the field of machine learning and artificial intelligence. She serves as a Director and Research Scientist at Google, where she has made significant contributions to the development of support-vector machines, artificial neural networks, and bioinformatics. Additionally, she holds positions as a Chaired Professor of Artificial Intelligence, INRIA researcher, and a full professor of data science and machine learning at Université Paris-Saclay. Throughout her career, Isabelle has shown a dedication to promoting openness in scientific communication and the peer-review process.
# ---
#
# Is	-0.00024275472
#
# abelle	-2.1054253e-05
#
#  Guy	-1.8624639e-06
#
# on	-6.1537958e-06
#
#  is	-0.07734606
#
#  a	-0.012759788
#
#  respected	-3.0701518
#
#  figure	-0.29617986
#
#  in	-0.0037839275
#
#  the	-0.07037407
#
#  field	-0.026333978
#
#  of	-1.6643718e-05
#
#  machine	-0.0003393959
#
#  learning	-3.7697225e-06
#
#  and	-2.1955578
#
#  artificial	-1.1398609
#
#  intelligence	-4.00813e-06
#
# .	-0.6013753
#
#  She	-0.1729713
#
#  serves	-1.5692084
#
#  as	-0.0038390253
#
#  a	-0.8969406
#
#  Director	-0.0027091769
#
#  and	-0.011115029
#
#  Research	-6.718607e-05
#
#  Scientist	-5.6769813e-06
#
#  at	-0.00013607845
#
#  Google	-6.9882217e-06
#
# ,	-0.14403898
#
#  where	-2.238151
#
#  she	-0.009409899
#
#  has	-0.47013253
#
#  made	-0.16464381
#
#  significant	-0.058226418
#
#  contributions	-4.763667e-05
#
#  to	-0.22504431
#
#  the	-0.9177417
#
#  development	-0.111619286
#
#  of	-0.017411234
#
#  support	-0.00502276
#
# -vector	-0.0027069158
#
#  machines	-1.3306016e-05
#
# ,	-0.036703166
#
#  artificial	-0.018371524
#
#  neural	-3.888926e-06
#
#  networks	-4.723352e-06
#
# ,	-8.4828214e-05
#
#  and	-0.0075240512
#
#  bio	-0.0001506213
#
# informatics	-3.1281633e-07
#
# .	-0.00083095155
#
#  Additionally	-0.29257354
#
# ,	-3.1281633e-07
#
#  she	-0.48037758
#
#  holds	-0.093846045
#
#  positions	-0.7489235
#
#  as	-0.9969577
#
#  a	-0.009630239
#
#  Ch	-1.1108792
#
# aired	-2.5941605e-05
#
#  Professor	-3.619312e-05
#
#  of	-0.010294269
#
#  Artificial	-0.00072029565
#
#  Intelligence	-1.6166903e-05
#
# ,	-3.2773252
#
#  IN	-1.539506
#
# RIA	-7.743759e-05
#
#  researcher	-0.00071302796
#
# ,	-0.010058621
#
#  and	-0.006312924
#
#  a	-2.7566702
#
#  full	-0.027264519
#
#  professor	-0.0059917243
#
#  of	-0.062822446
#
#  data	-8.1490514e-05
#
#  science	-1.2664457e-06
#
#  and	-0.007833035
#
#  machine	-6.704273e-07
#
#  learning	-6.0345924e-06
#
#  at	-0.0068227625
#
#  Univers	-0.0016467305
#
# ité	-0.00014525715
#
#  Paris	-5.5577775e-06
#
# -S	-2.6968896e-06
#
# acl	-0.00013285996
#
# ay	-8.657073e-06
#
# .	-0.12865888
#
#  Throughout	-4.474283
#
#  her	-6.749814e-06
#
#  career	-0.00041720658
#
# ,	-1.92662e-05
#
#  Is	-0.5238591
#
# abelle	-8.061054e-06
#
#  has	-1.1016856
#
#  shown	-5.0081983
#
#  a	-0.12637335
#
#  dedication	-0.62805945
#
#  to	-7.0404574e-05
#
#  promoting	-0.09083697
#
#  openness	-0.02580808
#
#  in	-0.0010702044
#
#  scientific	-0.00022547018
#
#  communication	-0.0002007987
#
#  and	-0.0013163087
#
#  the	-0.8359381
#
#  peer	-0.0042487583
#
# -review	-0.00035858402
#
#  process	-1.8624639e-06
#
# .	-0.104280576
#
#
# ++++
#
# Query: Ping Hu (Boston University)
#
#
# Search Results:
#
# title: Ping Hu
# snippet: Biography. Ping Hu is a professor with the School of Computer ... degree in the Image and Video Computing (IVC) Group at Boston University, advised by Prof.
# ---
#
# title: Ping Hu - ORISE Fellow - FDA
# snippet: Ping Hu. Ph.D., MHS. FDA Johns Hopkins Bloomberg School of Public Health. Baltimore, Maryland, United States. 554 followers 500+ connections.
# ---
#
# title: Ping Hu - Google 学术搜索
# snippet: UESTC - ‪‪引用次数：1726 次‬‬ - ‪Computer Vision‬ - ‪Deep Learning‬ - ‪Image/Video Processing‬
# ---
#
# title: Ping Hu - Samsung Austin Research and Development ...
# snippet: I obtain my Ph.D. degree in Computer Science, Stony Brook University, under the supervisor of Distinguished Professor Arie Kaufman.
# ---
#
# title: Andrew Emili, Ph.D.
# snippet: Pingzhao Hu, PhD, computational biology, now Assist. Prof. (Univ. of Manitoba). 9/2005-6/2011 Dr. Clement Chung, PhD, computational biology, now senior staff ...
# ---
#
# title: Kathryn Lunetta | SPH
# snippet: Biography. Kathryn L. Lunetta, Ph.D. is a Professor of Biostatistics and a statistical geneticist with more than 20 years of experience in ...
# ---
#
# title: Julie Palmer | SPH
# snippet: Biography. Dr. Palmer is a cancer epidemiologist based at the Slone Epidemiology Center, with research projects spanning cancer early detection, etiology, and ...
# ---
#
# title: Specific mesoderm subset derived from human pluripotent ...
# snippet: Specific mesoderm subset derived from human pluripotent stem cells ameliorates microvascular pathology in type 2 diabetic mice. Chang-Hyun Gil, ...
# ---
#
# title: Editors | Scientific Reports
# snippet: Our Editors. Scientific Reports is run by a team of experienced editors who are experts in their fields. From our Editorial Board Members and Senior ...
# ---
#
#
# Ping Hu is a professor at Boston University with a Ph.D. in Computer Science from Stony Brook University. He specializes in Computer Vision, Deep Learning, and Image/Video Processing, and has conducted research in these areas during his academic career.
# ---
#
# Ping	-0.0023817115
#
#  Hu	-6.0345924e-06
#
#  is	-0.007681277
#
#  a	-0.00078425667
#
#  professor	-0.041602705
#
#  at	-0.24640995
#
#  Boston	-0.06431005
#
#  University	-1.6762922e-05
#
#  with	-1.1905174
#
#  a	-0.9384703
#
#  Ph	-0.2042457
#
# .D	-1.3067608e-05
#
# .	-0.0005245577
#
#  in	-0.41838786
#
#  Computer	-0.09023491
#
#  Science	-0.00015753144
#
#  from	-0.04143618
#
#  Ston	-0.00017517358
#
# y	-1.6240566e-06
#
#  Brook	-2.9279307e-05
#
#  University	-9.253091e-06
#
# .	-0.065003775
#
#  He	-0.6959545
#
#  specializes	-0.5405224
#
#  in	-7.89631e-07
#
#  Computer	-0.711186
#
#  Vision	-4.365741e-06
#
# ,	-0.002232094
#
#  Deep	-0.00013774731
#
#  Learning	-1.6166903e-05
#
# ,	-1.92662e-05
#
#  and	-0.056295324
#
#  Image	-5.0497558e-05
#
# /	-0.00018137218
#
# Video	-6.945094e-05
#
#  Processing	-0.00010640408
#
# ,	-1.3683167
#
#  and	-0.7711886
#
#  has	-0.1075036
#
#  conducted	-1.8210998
#
#  research	-0.00151117
#
#  in	-0.32819912
#
#  these	-0.31314847
#
#  areas	-0.01566771
#
#  during	-1.1977001
#
#  his	-5.3596854e-05
#
#  academic	-0.017981939
#
#  career	-0.003987335
#
# .	-0.013820964
#
#
# ++++
#
# Query: Erin Grant (University College London)
#
#
# Search Results:
#
# title: Erin Grant | Home
# snippet: Senior Research Fellow at University College London researching biological and artificial intelligence.
# ---
#
# title: Erin Grant
# snippet: Laurent Ferron. Research Fellow at University College London. London ; Aniruddh Galgali. Machine Learning & Computational Neuroscience @ Gatsby Computational ...
# ---
#
# title: Erin Grant
# snippet: Erin Grant. Senior Research Fellow, University College London. Verified email at ucl.ac.uk - Homepage · Machine LearningCognitive ScienceNeuroscience.
# ---
#
# title: Erin Grant Profile | University College London
# snippet: View the University College London profile of Erin Grant. Including their publications.
# ---
#
# title: Erin Grant (@ermgrant) / X
# snippet: Senior Research Fellow @GatsbyUCL & @SWC_Neuro {learning, representations, structure} in @eringrant@sigmoid.social @eringrant@bsky.social.
# ---
#
# title: Erin Grant Publications | University College London
# snippet: View the University College London profile of Erin Grant. Including their publications.
# ---
#
# title: Speakers - Gender Based Analysis Plus – February 22
# snippet: Erin Grant's bio. Erin has 9 years of experience working in the BC Government ... School of Business, York University and Northwestern University, Kellogg School ...
# ---
#
# title: Erin Grant
# snippet: Education & Career History ; Postdoc. University College London (ucl.ac.uk). 2022 · Present ; PhD student. University of California, Berkeley (berkeley.edu). 2016 ...
# ---
#
# title: Speakers - Gender Based Analysis Plus – February 16
# snippet: Erin is a Senior Policy and Legislative Analyst with the Office of the Chief Information Officer, as well as a Gender Equity Advisor to the Gender Equity ...
# ---
#
#
# Erin Grant is a Senior Research Fellow at University College London where she focuses on researching biological and artificial intelligence. Erin's work involves machine learning, cognitive science, and neuroscience, with a particular interest in learning, representations, and structure within these fields.
# ---
#
# Er	-3.3451433e-05
#
# in	-1.9361265e-07
#
#  Grant	-5.2001665e-06
#
#  is	-0.00064952904
#
#  a	-0.0022066394
#
#  Senior	-0.00089335564
#
#  Research	-4.604148e-06
#
#  Fellow	-1.147242e-06
#
#  at	-0.00021724513
#
#  University	-0.000442232
#
#  College	-1.147242e-06
#
#  London	-1.5451682e-05
#
#  where	-5.661384
#
#  she	-0.05373513
#
#  focuses	-0.64480454
#
#  on	-0.054699343
#
#  researching	-0.09915552
#
#  biological	-0.0039270143
#
#  and	-1.0206721e-05
#
#  artificial	-3.1281633e-07
#
#  intelligence	-1.147242e-06
#
# .	-0.0543695
#
#  Erin	-1.4898381
#
# 's	-0.6238263
#
#  work	-0.7503644
#
#  involves	-0.79750514
#
#  machine	-0.10697481
#
#  learning	-7.3458323e-06
#
# ,	-0.00021307668
#
#  cognitive	-0.018387437
#
#  science	-2.0219828e-05
#
# ,	-8.1490514e-05
#
#  and	-0.0020426023
#
#  neuroscience	-1.9385403e-05
#
# ,	-1.0948925
#
#  with	-2.6190028
#
#  a	-0.06673519
#
#  particular	-0.43515345
#
#  interest	-0.031043706
#
#  in	-1.7432603e-06
#
#  learning	-0.020313192
#
# ,	-0.00891496
#
#  representations	-0.0002290463
#
# ,	-3.5835506e-05
#
#  and	-5.383526e-05
#
#  structure	-0.013848472
#
#  within	-2.1692104
#
#  these	-0.04350446
#
#  fields	-0.109199695
#
# .	-0.002206282
#
#
# ++++
#
# Query: Konstantina Palla (Spotify)
#
#
# Search Results:
#
# title: Konstantina Palla - Senior Researcher - Spotify
# snippet: A pure Bayesian in education, I spent years building probabilistic models that uncover the latent structure in data. My work focused on methodology and was ...
# ---
#
# title: Konstantina Palla
# snippet: I am a senior research scientist at Spotify research working with a great team in London, UK. Before that, I was a senior researcher at Microsoft Research ...
# ---
#
# title: Konstantina Palla's Post
# snippet: Spotifier Konstantina Palla opening the Women in Machine Learning workshop at NeurIPS 2022. Spotify is a proud sponsor of this amazing and ...
# ---
#
# title: NeurIPS 2023 conference
# snippet: Affinity Workshop Chair. Arjun Subramonian (University of California, Los Angeles) Blessing Ogbuokiri (York University) Konstantina Palla (Spotify). Diversity ...
# ---
#
# title: Konstantina Palla
# snippet: Konstantina Palla is a senior Spotify research scientist, leading efforts that explore the use of AI for content moderation.
# ---
#
# title: WiML2022 - Program
# snippet: ... Konstantina Palla (Senior Program Chair). 8:45 am - 9:00 am D&I Chair ... Recommender systems: Mounia Lalmas-Roelke (Spotify). Reinforcement ...
# ---
#
# title: The Greek AI Ecosystem - The Greek Analyst - Substack
# snippet: At Spotify, one will find Konstantina Palla and Athanasios Vlontzos, two young bright scientists that apply their AI research to real-world ...
# ---
#
# title: NeurIPS 2023
# snippet: Blessing Ogbuokiri (York University). Konstantina Palla (Spotify Research). Outreach Chair. Edward Choi (KAIST). Jihun Hamm (Tulane University). Program Chair ...
# ---
#
# title: 2023 2.3 Creativity and ML - Konstantina Palla - YouTube
# snippet: 2023 2.3 Creativity and ML - Konstantina Palla. 107 views · 5 months ago ...more. Mediterranean Machine Learning (M2L) summer school. 1.84K.
# ---
#
#
# Konstantina Palla is a senior research scientist at Spotify. She has expertise in Bayesian methods and has worked on building probabilistic models to uncover hidden patterns in data. Currently, she is leading efforts to explore the use of AI for content moderation at Spotify.
# ---
#
# Kon	-0.0002224901
#
# stant	-1.4140442e-05
#
# ina	-3.7697225e-06
#
#  P	-1.3856493e-06
#
# alla	-6.0345924e-06
#
#  is	-0.0168824
#
#  a	-0.00067335507
#
#  senior	-0.273882
#
#  research	-0.35992628
#
#  scientist	-3.4121115e-06
#
#  at	-0.0023410427
#
#  Spotify	-2.3392786e-06
#
# .	-6.712934
#
#  She	-0.14735825
#
#  has	-0.57454866
#
#  expertise	-1.5736971
#
#  in	-7.8033605e-05
#
#  Bayesian	-1.4735148
#
#  methods	-0.86123884
#
#  and	-0.12801531
#
#  has	-3.056456
#
#  worked	-0.17241122
#
#  on	-0.03298998
#
#  building	-0.5895224
#
#  probabil	-0.00049798633
#
# istic	-4.1273333e-06
#
#  models	-7.107425e-06
#
#  to	-0.033167236
#
#  uncover	-0.46367413
#
#  hidden	-1.5546587
#
#  patterns	-0.15099272
#
#  in	-0.046563257
#
#  data	-7.3742274e-05
#
# .	-0.0042336816
#
#  Currently	-3.1788745
#
# ,	-1.8837969
#
#  she	-0.076926254
#
#  is	-2.105783
#
#  leading	-0.14529237
#
#  efforts	-0.47008306
#
#  to	-2.3794832
#
#  explore	-0.060315706
#
#  the	-0.0062552313
#
#  use	-0.42327303
#
#  of	-9.0883464e-07
#
#  AI	-0.104066506
#
#  for	-0.011270394
#
#  content	-3.650519e-06
#
#  moderation	-9.0883464e-07
#
#  at	-0.10821732
#
#  Spotify	-0.00049322186
#
# .	-0.025521552
#
#
# ++++
#
# Query: Talha Irfan (UET, Lahore)
#
#
# Search Results:
#
# title: Talha Irfan - Content Writer - Apify
# snippet: I have been writing on DL and Hugging Face. University of Engineering and Technology, Lahore Graphic. Machine Learning Researcher. University of Engineering and ...
# ---
#
# title: Talha Irfan - Faisalabad District, Punjab, Pakistan
# snippet: View Talha Irfan's profile on LinkedIn, the world's largest professional community. Talha's ... Student at University of Engineering and Technology, Lahore.
# ---
#
# title: Talha IRFAN | University of Engineering and Technology ...
# snippet: Talha Irfan. University of Engineering and Technology, Lahore | UET · Center for Advancement of Textile Engineering and Technology.
# ---
#
# title: University of Engineering and Technology, Lahore
# snippet: Talha Irfan. Department. Center for Advancement of Textile Engineering and Technology. Disciplines. Engineering Management · Ume Habiba.
# ---
#
# title: NeurIPS 2023 conference
# snippet: Talha Irfan (UET, Lahore). Logistics and IT. Brad Brockmeyer (NeurIPS Foundation) Brian Nettleton (EventHosts) Lee Campbell (NeurIPS / Eventhosts) Mary Ellen ...
# ---
#
# title: Undergraduate | Prospectus | 2021
# snippet: University of Engineering and Technology, Lahore, enjoys a respectable position as a leading institution amongst the reputed engineering ...
# ---
#
# title: UNIVERSITY OF ENGINEERING & TECHNOLOGY, LAHORE
# snippet: most important areas of bio medical engineering. Biomechanics will ... A list of selectees will be put up on the University notice boards and on.
# ---
#
# title: Postgraduate Prospectus 2022 www.uet.edu.pk 1 1
# snippet: ... (UET), Lahore, Lahore College for Women University (LWCU),. 15. Lahore and ... c) The University authorities reserve the right to make any changes in the ...
# ---
#
# title: Irfan Ullah Chaudhary
# snippet: Technical Director. Introduced energy efficient, environmentally friendly innovations to increase productivity of the plant. Systems (Pvt.) Ltd., Lahore.
# ---
#
#
# Talha Irfan is a student at the University of Engineering and Technology in Lahore, specializing in Textile Engineering and Technology. He has a keen interest in machine learning and has been involved in research in that field. Additionally, Talha has represented his university at conferences such as NeurIPS 2023, showcasing his expertise in logistics and IT.
# ---
#
# T	-8.613945e-05
#
# al	-7.9418505e-06
#
# ha	-3.650519e-06
#
#  I	-8.061054e-06
#
# rf	-6.704273e-07
#
# an	-3.0545007e-06
#
#  is	-0.0013732073
#
#  a	-0.0038801196
#
#  student	-0.019766478
#
#  at	-0.009174045
#
#  the	-0.009474621
#
#  University	-4.4849444e-06
#
#  of	-3.4121115e-06
#
#  Engineering	-3.0545007e-06
#
#  and	-5.6457742e-05
#
#  Technology	-6.0345924e-06
#
#  in	-1.1545527
#
#  Lahore	-7.703444e-06
#
# ,	-0.21644711
#
#  specializing	-0.5490808
#
#  in	-3.523949e-05
#
#  Text	-0.5766821
#
# ile	-5.080963e-06
#
#  Engineering	-3.2497806e-05
#
#  and	-0.013872341
#
#  Technology	-0.00058496464
#
# .	-0.0078243995
#
#  He	-0.3796061
#
#  has	-1.51691
#
#  a	-1.7147
#
#  keen	-1.1400844
#
#  interest	-0.0005263421
#
#  in	-0.0023654208
#
#  machine	-0.7795573
#
#  learning	-9.610702e-06
#
#  and	-0.6754567
#
#  has	-0.47375503
#
#  been	-0.5823678
#
#  involved	-0.11495549
#
#  in	-0.0012454705
#
#  research	-0.12519832
#
#  in	-0.27610606
#
#  that	-2.1216896
#
#  field	-0.13785431
#
# .	-0.05010219
#
#  Additionally	-0.7792791
#
# ,	-1.2664457e-06
#
#  Tal	-0.6711711
#
# ha	-1.4617256e-05
#
#  has	-0.07397963
#
#  represented	-9999.0
#
#  his	-1.7123809
#
#  university	-0.015960816
#
#  at	-0.118514
#
#  conferences	-1.5235876
#
#  such	-0.5263851
#
#  as	-4.246537e-06
#
#  Ne	-0.0057429676
#
# ur	-1.6762922e-05
#
# IPS	-3.888926e-06
#
#  	-0.47685075
#
# 202	-1.27099975e-05
#
# 3	-9.4914985e-06
#
# ,	-0.854169
#
#  showcasing	-0.5175364
#
#  his	-0.0023428272
#
#  expertise	-0.30930626
#
#  in	-0.005535162
#
#  logistics	-0.03484535
#
#  and	-5.7530575e-05
#
#  IT	-0.041551236
#
# .	-0.12554587
#
#
# ++++
#
# Query: Moritz Hardt (Max Planck Institute for Intelligent Systems, Tübingen)
#
#
# Search Results:
#
# title: Moritz Hardt
# snippet: I'm a director at the Max Planck Institute for Intelligent Systems. Prior to joining the institute, I was Associate Professor for Electrical Engineering and ...
# ---
#
# title: Moritz Hardt appointed a Director at the Max Planck Institute ...
# snippet: Tübingen – Computer scientist Moritz Hardt, Ph.D., has accepted a call to the Max Planck Institute for Intelligent Systems. He joined the ...
# ---
#
# title: Moritz Hardt
# snippet: Education & Career History. Principal Researcher. Max-Planck-Institute for Intelligent Systems, Max-Planck Institute ... Select a topic or type what you need help ...
# ---
#
# title: Moritz Hardt | EECS at UC Berkeley
# snippet: Moritz Hardt is an Associate Professor in the Department of Electrical Engineering and Computer Sciences at the University of California, Berkeley.
# ---
#
# title: Discovering discrimination in supervised learning
# snippet: Biography: Moritz Hardt is a senior research scientist at Google ... Max Planck Institute for Intelligent Systems. Max-Planck-Ring 4 72076 ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: Moritz Hardt founded the department "Social Foundations of Computation" in 2021, which extends the institute's deep expertise in machine learning, artificial ...
# ---
#
# title: Moritz Hardt
# snippet: Max Planck Institute for Intelligent Systems - ‪‪Cited by 29624‬‬ - ‪algorithms‬ - ‪decision making‬ - ‪machine learning‬
# ---
#
# title: PhD Students
# snippet: Alexander Immer. My research focuses on probabilistic machine learning and data science. Currently, I am particularly interested in approximate inference ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: We take a highly interdisciplinary approach that combines mathematics, computation, materials science, and biology. The Max Planck Institute for Intelligent ...
# ---
#
#
# Moritz Hardt is a Computer Scientist who has been appointed as a Director at the Max Planck Institute for Intelligent Systems in Tübingen. Previously, he was an Associate Professor for Electrical Engineering and Computer Sciences at UC Berkeley. He has founded a department focused on the "Social Foundations of Computation," expanding the institute's expertise in machine learning and artificial intelligence.
# ---
#
# Mor	-0.0050959494
#
# itz	-1.8624639e-06
#
#  Hard	-3.888926e-06
#
# t	-0.00011427152
#
#  is	-0.13182428
#
#  a	-0.09934075
#
#  Computer	-3.3890634
#
#  Scientist	-0.22221234
#
#  who	-1.5881399
#
#  has	-2.2710612
#
#  been	-0.34854066
#
#  appointed	-0.0011036602
#
#  as	-0.012910191
#
#  a	-0.008552165
#
#  Director	-0.027187146
#
#  at	-0.00012618455
#
#  the	-0.00041267683
#
#  Max	-4.00813e-06
#
#  Plan	-3.3809047e-05
#
# ck	0.0
#
#  Institute	-6.9882217e-06
#
#  for	-1.247159e-05
#
#  Intelligent	-5.080963e-06
#
#  Systems	-1.6166903e-05
#
#  in	-0.061463133
#
#  T	-0.00014621076
#
# ü	-5.5122365e-07
#
# bing	-7.89631e-07
#
# en	-2.8921695e-05
#
# .	-0.028592689
#
#  Previously	-2.6229823
#
# ,	-0.015987912
#
#  he	-0.015421344
#
#  was	-0.55077595
#
#  an	-0.012982916
#
#  Associate	-0.00024108587
#
#  Professor	-1.2664457e-06
#
#  for	-0.830805
#
#  Electrical	-2.3676734e-05
#
#  Engineering	-2.1008714e-06
#
#  and	-0.017630162
#
#  Computer	-0.0062911296
#
#  Sciences	-0.010413667
#
#  at	-0.00060224184
#
#  UC	-0.4916021
#
#  Berkeley	-0.00038479414
#
# .	-0.08677115
#
#  He	-1.2909274
#
#  has	-0.7436421
#
#  founded	-2.8306456
#
#  a	-2.3605998
#
#  department	-0.032647833
#
#  focused	-1.9549329
#
#  on	-6.704273e-07
#
#  the	-0.08476894
#
#  "	-0.035449706
#
# Social	-1.1637165e-05
#
#  Foundations	-0.00016766376
#
#  of	-1.6240566e-06
#
#  Com	-5.5122365e-07
#
# putation	-2.4584822e-06
#
# ,"	-2.7695239
#
#  expanding	-0.8576723
#
#  the	-0.01179008
#
#  institute	-0.049885035
#
# 's	-0.0021043406
#
#  expertise	-0.0704323
#
#  in	-0.0006460758
#
#  machine	-0.06450231
#
#  learning	-7.9418505e-06
#
#  and	-0.037877712
#
#  artificial	-0.0019305398
#
#  intelligence	-2.220075e-06
#
# .	-0.0048888423
#
#
# ++++
#
# Query: Irene Chen (UC Berkeley)
#
#
# Search Results:
#
# title: Irene Y. Chen - UC Berkeley and UCSF
# snippet: Professor Irene Chen studies machine learning for equitable healthcare. Her research focuses on two main areas: 1) developing machine learning methods for ...
# ---
#
# title: Irene Chen - University of California, Berkeley
# snippet: I am an Assistant Professor at UC Berkeley and UCSF in Computational Precision Health and… | Learn more about Irene Chen's work experience, education, ...
# ---
#
# title: Rising Star 2020 Irene Chen
# snippet: Bio. Irene Chen is a computer science PhD student at MIT, advised by David Sontag. Her research focuses on machine learning methods to improve clinical care ...
# ---
#
# title: Irene Chen
# snippet: Irene Chen is a machine learning researcher broadly interested in computational methods to improve healthcare for the entire patient population. She ...
# ---
#
# title: Irene Chen (@irenetrampoline) / X
# snippet: ML for equitable healthcare. Assistant Professor @UCBerkeley and @UCSF. Prev @Harvard, @MIT, @MSFTResearch. Cambridge, MA. irenechen.net.
# ---
#
# title: Advising Statement | Irene Y. Chen - UC Berkeley and UCSF
# snippet: One of my goals as an advisor for postdocs, PhD students, and undergraduate researchers in the lab is to train the next generation of researchers.
# ---
#
# title: Irene Y. Chen
# snippet: Irene Y. Chen. Assistant Professor, UC Berkeley and UC San Francisco. Verified email at berkeley.edu - Homepage · machine learninghealthcareequity ...
# ---
#
# title: Irene Chen's Post
# snippet: Beforehand starting Aug 2022, I'll be a Postdoc at Microsoft Research in the New England office. Excited to continue my work on Machine Learning ...
# ---
#
# title: Resources | Irene Y. Chen - UC Berkeley and UCSF
# snippet: Advice for aspiring and current ML researchers, where to present research on machine learning, healthcare, and/or fairness.
# ---
#
#
# Irene Chen is an Assistant Professor at UC Berkeley and UCSF, focusing on machine learning for equitable healthcare. With a background in computer science and a research interest in computational methods to improve healthcare outcomes for patients, she is dedicated to training the next generation of researchers in this field.
# ---
#
# I	-0.0044983653
#
# rene	-1.2948405e-05
#
#  Chen	-0.009240184
#
#  is	-0.0044137402
#
#  an	-0.017894246
#
#  Assistant	-0.0017456237
#
#  Professor	-1.0280384e-06
#
#  at	-0.0013651161
#
#  UC	-0.01452333
#
#  Berkeley	-6.749814e-06
#
#  and	-0.0013644046
#
#  UCS	-0.023507396
#
# F	-1.9816675e-06
#
# ,	-0.20074639
#
#  focusing	-1.3757863
#
#  on	-0.08499048
#
#  machine	-0.09269888
#
#  learning	-1.6166903e-05
#
#  for	-0.73536056
#
#  equitable	-0.0009549326
#
#  healthcare	-4.8425554e-06
#
# .	-0.018730301
#
#  With	-2.1007676
#
#  a	-0.026421517
#
#  background	-0.022212647
#
#  in	-0.0019150726
#
#  computer	-1.499931
#
#  science	-2.577686e-06
#
#  and	-0.18702611
#
#  a	-0.2685523
#
#  research	-1.3522785
#
#  interest	-0.04561149
#
#  in	-0.00023643693
#
#  computational	-0.3292478
#
#  methods	-0.0061316565
#
#  to	-0.0072963857
#
#  improve	-0.1778768
#
#  healthcare	-0.0055307806
#
#  outcomes	-0.66019315
#
#  for	-0.8543253
#
#  patients	-1.641711
#
# ,	-0.02925141
#
#  she	-2.36123
#
#  is	-0.16848592
#
#  dedicated	-0.14311278
#
#  to	-5.0497558e-05
#
#  training	-0.077826895
#
#  the	-0.001499268
#
#  next	-0.00032831362
#
#  generation	-2.577686e-06
#
#  of	-5.9153886e-06
#
#  researchers	-4.3464544e-05
#
#  in	-0.23828195
#
#  this	-0.9215984
#
#  field	-0.00525878
#
# .	-0.0036781093
#
#
# ++++
#
# Query: Pascal Notin (Department of Computer Science, University of Oxford)
#
#
# Search Results:
#
# title: Pascal Notin
# snippet: I am a Scientific Lead in the Marks lab at Harvard Medical school, where I lead the subgroup focusing on protein engineering. My research lies at the ...
# ---
#
# title: Pascal Notin - Boston, Massachusetts, United States
# snippet: Scientific Lead in the Marks lab at Harvard Medical school • Research at the intersection of generative AI, computational biology and chemistry
# ---
#
# title: Pascal Notin - OATML
# snippet: Pascal is a DPhil student in the CS Department at Oxford University, supervised by Yarin Gal. He is interested in advancing existing machine learning ...
# ---
#
# title: Pascal Notin
# snippet: Pascal Notin. Department of Computer Science, University of Oxford. Verified email at cs.ox.ac.uk - Homepage · Artificial IntelligenceGenerative ...
# ---
#
# title: Pascal Notin
# snippet: Pascal Notin. Personal photo - Pascal Notin. Pascal Notin. Doctoral Student. Student, St Cross College. Leaving date: 15th December 2023 ...
# ---
#
# title: Pascal Notin's research works | University of Oxford ...
# snippet: Pascal Notin's 16 research works with 334 citations and 1801 reads, including: Machine learning for functional protein design.
# ---
#
# title: Pascal Notin (@NotinPascal) / X
# snippet: Research in AI for Protein Design @Harvard | Prev. CS PhD @UniofOxford, Digital & Analytics @McKinsey, Maths & Physics @Polytechnique.
# ---
#
# title: Learning from prepandemic data to forecast viral escape
# snippet: OATML Group, Department of Computer Science, University of Oxford, Oxford, UK. Pascal Notin & Yarin Gal. Broad Institute of Harvard and MIT ...
# ---
#
# title: ProteinGym: Large-Scale Benchmarks for Protein Design ...
# snippet: Pascal Notin, Computer Science, University of Oxford. Aaron W. Kollasch, Systems Biology, Harvard Medical School. Daniel Ritter, Systems Biology, Harvard ...
# ---
#
# title: Blaise Pascal
# snippet: Following a religious experience in late 1654, he began writing influential works on philosophy and theology. His two most famous works date from this period: ...
# ---
#
#
# Pascal Notin is a DPhil student in the Department of Computer Science at the University of Oxford, supervised by Yarin Gal. His research interests revolve around advancing machine learning techniques, particularly in the field of generative AI, and their applications to computational biology and protein engineering.
# ---
#
# P	-0.00030781425
#
# ascal	-1.9361265e-07
#
#  Not	-3.9650025e-05
#
# in	-1.9743013e-05
#
#  is	-0.0020683026
#
#  a	-0.022192605
#
#  D	-0.9684286
#
# Phil	-2.6299214e-05
#
#  student	-0.0010337611
#
#  in	-0.07334831
#
#  the	-0.0001558626
#
#  Department	-0.54132694
#
#  of	-1.9361265e-07
#
#  Computer	-6.704273e-07
#
#  Science	-5.4385737e-06
#
#  at	-1.5332478e-05
#
#  the	-0.06545575
#
#  University	-9.0883464e-07
#
#  of	-1.504853e-06
#
#  Oxford	-3.5313153e-06
#
# ,	-0.22165255
#
#  supervised	-0.19315886
#
#  by	-1.6240566e-06
#
#  Y	-0.0011776087
#
# arin	-2.9352968e-06
#
#  Gal	-7.822647e-06
#
# .	-0.01621478
#
#  His	-0.06056784
#
#  research	-0.0028838066
#
#  interests	-0.16149992
#
#  rev	-2.2878006
#
# olve	-5.2001665e-06
#
#  around	-5.5122365e-07
#
#  advancing	-0.023191199
#
#  machine	-0.104804344
#
#  learning	-3.3093824e-05
#
#  techniques	-0.43080345
#
# ,	-0.3924905
#
#  particularly	-0.10524588
#
#  in	-0.008663971
#
#  the	-0.001853316
#
#  field	-0.3969407
#
#  of	-1.504853e-06
#
#  gener	-1.7342095
#
# ative	-2.9352968e-06
#
#  AI	-1.2642397
#
# ,	-2.2393756
#
#  and	-1.9613538
#
#  their	-0.5143634
#
#  applications	-0.33989176
#
#  to	-1.8973368
#
#  computational	-1.0048964
#
#  biology	-1.7597347e-05
#
#  and	-0.87920856
#
#  protein	-0.5592983
#
#  engineering	-0.41026425
#
# .	-0.013960631
#
#
# ++++
#
# Query: Moritz Hardt (Max Planck Institute for Intelligent Systems, Tübingen)
#
#
# Search Results:
#
# title: Moritz Hardt
# snippet: I'm a director at the Max Planck Institute for Intelligent Systems. Prior to joining the institute, I was Associate Professor for Electrical Engineering and ...
# ---
#
# title: Moritz Hardt appointed a Director at the Max Planck Institute ...
# snippet: Tübingen – Computer scientist Moritz Hardt, Ph.D., has accepted a call to the Max Planck Institute for Intelligent Systems. He joined the ...
# ---
#
# title: Moritz Hardt
# snippet: Education & Career History. Principal Researcher. Max-Planck-Institute for Intelligent Systems, Max-Planck Institute ... Select a topic or type what you need help ...
# ---
#
# title: Moritz Hardt | EECS at UC Berkeley
# snippet: Moritz Hardt is an Associate Professor in the Department of Electrical Engineering and Computer Sciences at the University of California, Berkeley.
# ---
#
# title: Discovering discrimination in supervised learning
# snippet: Biography: Moritz Hardt is a senior research scientist at Google ... Max Planck Institute for Intelligent Systems. Max-Planck-Ring 4 72076 ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: Moritz Hardt founded the department "Social Foundations of Computation" in 2021, which extends the institute's deep expertise in machine learning, artificial ...
# ---
#
# title: Moritz Hardt
# snippet: Max Planck Institute for Intelligent Systems - ‪‪Cited by 29624‬‬ - ‪algorithms‬ - ‪decision making‬ - ‪machine learning‬
# ---
#
# title: PhD Students
# snippet: Alexander Immer. My research focuses on probabilistic machine learning and data science. Currently, I am particularly interested in approximate inference ...
# ---
#
# title: Max Planck Institute for Intelligent Systems
# snippet: We take a highly interdisciplinary approach that combines mathematics, computation, materials science, and biology. The Max Planck Institute for Intelligent ...
# ---
#
#
# Moritz Hardt is a Computer Scientist who has been appointed as a Director at the Max Planck Institute for Intelligent Systems in Tübingen. Previously, he was an Associate Professor for Electrical Engineering and Computer Sciences at UC Berkeley. He has founded a department focused on the "Social Foundations of Computation," expanding the institute's expertise in machine learning and artificial intelligence.
# ---
#
# Mor	-0.0050959494
#
# itz	-1.8624639e-06
#
#  Hard	-3.888926e-06
#
# t	-0.00011427152
#
#  is	-0.13182428
#
#  a	-0.09934075
#
#  Computer	-3.3890634
#
#  Scientist	-0.22221234
#
#  who	-1.5881399
#
#  has	-2.2710612
#
#  been	-0.34854066
#
#  appointed	-0.0011036602
#
#  as	-0.012910191
#
#  a	-0.008552165
#
#  Director	-0.027187146
#
#  at	-0.00012618455
#
#  the	-0.00041267683
#
#  Max	-4.00813e-06
#
#  Plan	-3.3809047e-05
#
# ck	0.0
#
#  Institute	-6.9882217e-06
#
#  for	-1.247159e-05
#
#  Intelligent	-5.080963e-06
#
#  Systems	-1.6166903e-05
#
#  in	-0.061463133
#
#  T	-0.00014621076
#
# ü	-5.5122365e-07
#
# bing	-7.89631e-07
#
# en	-2.8921695e-05
#
# .	-0.028592689
#
#  Previously	-2.6229823
#
# ,	-0.015987912
#
#  he	-0.015421344
#
#  was	-0.55077595
#
#  an	-0.012982916
#
#  Associate	-0.00024108587
#
#  Professor	-1.2664457e-06
#
#  for	-0.830805
#
#  Electrical	-2.3676734e-05
#
#  Engineering	-2.1008714e-06
#
#  and	-0.017630162
#
#  Computer	-0.0062911296
#
#  Sciences	-0.010413667
#
#  at	-0.00060224184
#
#  UC	-0.4916021
#
#  Berkeley	-0.00038479414
#
# .	-0.08677115
#
#  He	-1.2909274
#
#  has	-0.7436421
#
#  founded	-2.8306456
#
#  a	-2.3605998
#
#  department	-0.032647833
#
#  focused	-1.9549329
#
#  on	-6.704273e-07
#
#  the	-0.08476894
#
#  "	-0.035449706
#
# Social	-1.1637165e-05
#
#  Foundations	-0.00016766376
#
#  of	-1.6240566e-06
#
#  Com	-5.5122365e-07
#
# putation	-2.4584822e-06
#
# ,"	-2.7695239
#
#  expanding	-0.8576723
#
#  the	-0.01179008
#
#  institute	-0.049885035
#
# 's	-0.0021043406
#
#  expertise	-0.0704323
#
#  in	-0.0006460758
#
#  machine	-0.06450231
#
#  learning	-7.9418505e-06
#
#  and	-0.037877712
#
#  artificial	-0.0019305398
#
#  intelligence	-2.220075e-06
#
# .	-0.0048888423
#
#
# ++++
